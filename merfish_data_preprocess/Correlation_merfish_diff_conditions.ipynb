# %%
import numpy as np
import pandas as pd
import seaborn as sns
import anndata
import scanpy as sc
import os

import matplotlib.pyplot as plt

sc.settings.n_jobs = 24
sc.settings.set_figure_params(dpi=180, dpi_save=300, frameon=False, figsize=(4, 4), fontsize=8, facecolor='white')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import anndata
import scanpy as sc
import os

# %%
merlin_output_folder = r'L:\Shiwei_Analysis\Analysis\20210717-P_brain_MO4_MERFISH_renamed_data_partial'

merlin_output_folder = r'L:\Shiwei\Analysis\20210717MO4'



# Load MERFISH data
counts_file_mer = os.path.join(merlin_output_folder, 'ExportPartitionedBarcodes', 'barcodes_per_feature.csv')
df = pd.read_csv(counts_file_mer).rename(columns={'Unnamed: 0':'index'}).set_index('index')

# %%
merlin_output_folder = r'L:\Shiwei\Analysis\20211230MO4_nonclear'



# Load MERFISH data
counts_file_mer_2 = os.path.join(merlin_output_folder, 'ExportPartitionedBarcodes', 'barcodes_per_feature.csv')
df_2 = pd.read_csv(counts_file_mer_2).rename(columns={'Unnamed: 0':'index'}).set_index('index')

# %%
df_2
# Out:
#                                          1700022I11Rik  1810046K07Rik  \
# index
# 101808820240203117455184041091640402179            0.0            0.0
# 103498865285145932727282945545527529102            0.0            0.0
# 103517295037125852093085051124525841100            0.0            0.0
# 1045818609346103801768591368789117883              0.0            0.0
# 104718763003569936484753411569730434974            0.0            0.0
# ...                                                ...            ...
# 96798364665991598883819515360257447774             0.0            0.0
# 97503467994969364652471263721297343860             0.0            0.0
# 9767021443239382399818848633311434736              0.0            0.0
# 98452576164188763297215825080314582958             0.0            0.0
# 98543933083549795964954846091320363867             0.0            0.0
#
#                                          5031425F14Rik  5730522E02Rik  Acta2  \
# index
# ...

# %%
merlin_output_folder = r'L:\Shiwei\Analysis\20211217MO4_nonclear'



# Load MERFISH data
counts_file_mer_4 = os.path.join(merlin_output_folder, 'ExportPartitionedBarcodes', 'barcodes_per_feature.csv')
df_4 = pd.read_csv(counts_file_mer_4).rename(columns={'Unnamed: 0':'index'}).set_index('index')

# %%
# %matplotlib notebook

df.values.shape

mean_df_1 = np.mean(df.values, axis=0)

mean_df_2 = np.mean(df_2.values, axis=0)


plt.scatter(np.log10(mean_df_1),np.log10(mean_df_3), s=3, c='black')

plt.ylabel('Average copy number/cell (uncleared) - Replicate #1',fontsize=11)
plt.xlabel('Average copy number/cell (cleared)',fontsize=11)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)

from scipy import stats

print(stats.pearsonr(np.log10(mean_df_1),np.log10(mean_df_2)))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0.948323797761663, 1.2426589222694175e-126)

# %%
# %matplotlib notebook



plt.scatter(np.log10(mean_df_2),np.log10(mean_df_3), s=3, c='black')

plt.ylabel('Average copy number/cell (uncleared) - Replicate #2',fontsize=11)
plt.xlabel('Average copy number/cell (uncleared) - Replicate #1',fontsize=11)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)

print(stats.pearsonr(np.log10(mean_df_2),np.log10(mean_df_3)))
# Out:
# <img src="data:image/png;base64,..." width="703.6363483854565">
# (0.9962289045743933, 1.9448955609283655e-267)

# %%
# %matplotlib notebook



plt.scatter(np.log10(mean_df_2),np.log10(mean_df_4), s=3, c='black')

plt.ylabel('Average copy number/cell (uncleared) - Replicate #3',fontsize=11)
plt.xlabel('Average copy number/cell (uncleared) - Replicate #1',fontsize=11)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)

print(stats.pearsonr(np.log10(mean_df_2),np.log10(mean_df_4)))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0.9856333785320515, 4.125570355074262e-195)

# %%
# %matplotlib notebook



plt.scatter(np.log10(mean_df_1),np.log10(mean_df_4), s=3, c='black')

plt.ylabel('Average copy number/cell (uncleared) - Replicate #3',fontsize=11)
plt.xlabel('Average copy number/cell (cleared)',fontsize=11)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)

print(stats.pearsonr(np.log10(mean_df_1),np.log10(mean_df_4)))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0.9614684376866464, 3.305238278287015e-142)

# %%
MOp_MERFISH_meng_preprocessed_for_integration_file =r'L:\Shiwei\Analysis\20211229MO4_nonclear_classifer/counts.h5ad'

merfish_raw = sc.read_h5ad(MOp_MERFISH_meng_preprocessed_for_integration_file)

merfish_label = pd.read_csv(r'L:\Shiwei\Analysis\20211229MO4_nonclear_classifer/cell_labels.csv', index_col=0)

# %%
merData = pd.DataFrame(merfish_raw.X, index = merfish_raw.obs.index, columns = merfish_raw.var.index)
labels = merfish_label.loc[merfish_label['label']!='-1']
merData
# Out:
# index                                    1700022I11Rik  1810046K07Rik  \
# index
# 10000143038275111136124942858811168393             0.0       0.000000
# 100001798412490480358118871918100400402            0.0       0.000000
# 100006878605830627922364612565348097824            0.0       0.000000
# 100007228202835962319771548915451072492            0.0       0.000000
# 100009332472089331948140672873134747603            0.0       0.491629
# ...                                                ...            ...
# 99987465505639073211021560543065098772             0.0       0.000000
# 99989592830367590092304100078674096866             0.0       0.000000
# 99991756591196613545069880666241120777             0.0       0.000000
# 99997421766159526763299676887100858104             0.0       0.000000
# 99997470167777465101376150817407669505             0.0       0.475026
#
# index                                    5031425F14Rik  5730522E02Rik  \
# index
# ...

# %%
df_5.head()

df_5.columns[:-12]
# Out:
# Index(['1700022I11Rik', '1810046K07Rik', '5031425F14Rik', '5730522E02Rik',
#        'Acta2', 'Adam2', 'Adamts2', 'Adamts4', 'Adra1b', 'Alk',
#        ...
#        'Unc13c', 'Unc5b', 'Unc5d', 'Ust', 'Vipr2', 'Vtn', 'Vwc2', 'Wipf3',
#        'Wnt7b', 'Zfp804b'],
#       dtype='object', name='index', length=242)

# %%
df_2.head()

df_2.columns[:-10]
# Out:
# Index(['1700022I11Rik', '1810046K07Rik', '5031425F14Rik', '5730522E02Rik',
#        'Acta2', 'Adam2', 'Adamts2', 'Adamts4', 'Adra1b', 'Alk',
#        ...
#        'Unc13c', 'Unc5b', 'Unc5d', 'Ust', 'Vipr2', 'Vtn', 'Vwc2', 'Wipf3',
#        'Wnt7b', 'Zfp804b'],
#       dtype='object', length=242)

# %%
df_2.columns[:-10] == df_5.columns[:-12]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df_2_sel = df_2.iloc[:,:-10]

df_1_sel = df.iloc[:,:-10]

df_5_sel = df_5.iloc[:,:-12]

# %%
# %matplotlib notebook

df.values.shape

#mean_df_1 = np.mean(df.values, axis=0)

mean_df_5_sel = np.mean(df_5_sel, axis=0)

mean_df_1_sel = np.mean(df_1_sel, axis=0)

mean_df_2_sel = np.mean(df_2_sel, axis=0)


plt.scatter(np.log10(mean_df_5_sel),np.log10(mean_df_2_sel), s=3, c='black')

plt.ylabel('Average copy number/cell (cleared) - Meng',fontsize=11)
plt.xlabel('Average copy number/cell (uncleared) - Replicate #1',fontsize=11)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)

from scipy import stats

print(stats.pearsonr(np.log10(mean_df_5_sel),np.log10(mean_df_2_sel)))
# Out:
# <img src="data:image/png;base64,..." width="800">
# (0.8874175767357735, 1.1051001080939388e-82)

# %%
# %matplotlib notebook

df.values.shape

#mean_df_1 = np.mean(df.values, axis=0)

mean_df_5_sel = np.mean(df_5_sel, axis=0)

mean_df_1_sel = np.mean(df_1_sel, axis=0)

mean_df_2_sel = np.mean(df_2_sel, axis=0)


plt.scatter(np.log10(mean_df_5_sel),np.log10(mean_df_1_sel), s=3, c='black')

plt.ylabel('Average copy number/cell (cleared) - Meng',fontsize=11)
plt.xlabel('Average copy number/cell (cleared) - ',fontsize=11)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)

from scipy import stats

print(stats.pearsonr(np.log10(mean_df_5_sel),np.log10(mean_df_1_sel)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.9394443337349064, 1.312578241955231e-113)
